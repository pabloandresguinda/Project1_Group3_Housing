# %% [markdown]
# # Import
# These should be the libraries we would need throughout this project. As long as we have our api keys that we need in our own .env file, this should work for everyone

# %%
import pandas as pd
import csv
import pprint as pprint
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
#import sklearn.datasets as dta
#from scipy.stats import linregress
#from scipy.stats import sem
import json
import requests
import os
from dotenv import load_dotenv
# Load .env enviroment variables into the notebook
load_dotenv()
# Get the API key from the environment variable and store as Python variable
weather_api_key = os.getenv("weather_api_key")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[21], line 15
#      13 from dotenv import load_dotenv
#      14 # Load .env enviroment variables into the notebook
# ---> 15 load_dotenv()
#      16 # Get the API key from the environment variable and store as Python variable
#      17 weather_api_key = os.getenv("weather_api_key")
#
# File /opt/anaconda3/envs/dev/lib/python3.10/site-packages/dotenv/main.py:346, in load_dotenv(dotenv_path, stream, verbose, override, interpolate, encoding)
#     329 """Parse a .env file and then load all the variables found as environment variables.
#     330
#     331 Parameters:
#    (...)
#     343 .env file.
#     344 """
#     345 if dotenv_path is None and stream is None:
# --> 346     dotenv_path = find_dotenv()
#     348 dotenv = DotEnv(
#     349     dotenv_path=dotenv_path,
#     350     stream=stream,
#    (...)
# ...

# %%
#Zillow ZHVI data 
filepath_zillow_zhvi = "data_sources/zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"
zhviraw = pd.read_csv(filepath_zillow_zhvi)
zhviraw.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
# 2     91940         3       77449        zip        TX    TX      Katy
# 3     62080         4       11368        zip        NY    NY  New York
# 4     91733         5       77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  210077.000246
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  137227.265500
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  103358.701090
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  146558.052897
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County  102016.821579
#
#    ...     2023-05-31     2023-06-30     2023-07-31     2023-08-31  \
# ...

# %%
all_columns = list(zhviraw.columns)
all_columns
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'State',
#  'City',
#  'Metro',
#  'CountyName',
#  '2000-01-31',
#  '2000-02-29',
#  '2000-03-31',
#  '2000-04-30',
#  '2000-05-31',
#  '2000-06-30',
#  '2000-07-31',
#  '2000-08-31',
#  '2000-09-30',
#  '2000-10-31',
#  '2000-11-30',
#  '2000-12-31',
#  '2001-01-31',
#  '2001-02-28',
#  '2001-03-31',
#  '2001-04-30',
#  '2001-05-31',
#  '2001-06-30',
#  '2001-07-31',
#  '2001-08-31',
#  '2001-09-30',
#  '2001-10-31',
#  '2001-11-30',
#  '2001-12-31',
#  '2002-01-31',
#  '2002-02-28',
#  '2002-03-31',
#  '2002-04-30',
#  '2002-05-31',
#  '2002-06-30',
#  '2002-07-31',
#  '2002-08-31',
#  '2002-09-30',
#  '2002-10-31',
#  '2002-11-30',
#  '2002-12-31',
#  '2003-01-31',
#  '2003-02-28',
#  '2003-03-31',
#  '2003-04-30',
#  '2003-05-31',
#  '2003-06-30',
#  '2003-07-31',
#  '2003-08-31',
#  '2003-09-30',
#  '2003-10-31',
#  '2003-11-30',
#  '2003-12-31',
#  '2004-01-31',
#  '2004-02-29',
#  '2004-03-31',
# ...

# %%
#city = "Seatlle"
seattle_only = zhviraw[zhviraw["City"]=="Seattle"]
pprint.pprint(seattle_only)
#Metro = "Seattle-Tacoma-Bellevue, WA"
stb = zhviraw[zhviraw["Metro"]=="Seattle-Tacoma-Bellevue, WA"]
# pprint.pprint(stb)
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 803       99565       815       98105        zip        WA    WA  Seattle
# 844       99575       857       98115        zip        WA    WA  Seattle
# 876       99563       889       98103        zip        WA    WA  Seattle
# 1270      99578      1288       98118        zip        WA    WA  Seattle
# 1325      99583      1343       98125        zip        WA    WA  Seattle
# 1713      99581      1736       98122        zip        WA    WA  Seattle
# 2279      99577      2306       98117        zip        WA    WA  Seattle
# 3075      99569      3111       98109        zip        WA    WA  Seattle
# 3864      99595      3907       98144        zip        WA    WA  Seattle
# 4325      99567      4374       98107        zip        WA    WA  Seattle
# 4341      99566      4390       98106        zip        WA    WA  Seattle
# 4638      99576      4691       98116        zip        WA    WA  Seattle
# ...

# %%
seattle_only.to_csv("data_sources/Seattle_zhiv.csv", index=False)
stb.to_csv("data_sources/metro_seattle_zhiv.csv", index=False)

# %%
filepath_kaggle_city = "data_sources/city_market_tracker.tsv000"
kaggle_city_raw = pd.read_csv(filepath_kaggle_city, delimiter=  "\t")
kaggle_city_raw
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 0         2021-02-01  2021-02-28               30       place               6
# 1         2019-04-01  2019-04-30               30       place               6
# 2         2020-08-01  2020-08-31               30       place               6
# 3         2018-11-01  2018-11-30               30       place               6
# 4         2013-02-01  2013-02-28               30       place               6
# ...              ...         ...              ...         ...             ...
# 5245042   2014-08-01  2014-08-31               30       place               6
# 5245043   2018-12-01  2018-12-31               30       place               6
# 5245044   2020-08-01  2020-08-31               30       place               6
# 5245045   2016-11-01  2016-11-30               30       place               6
# 5245046   2023-02-01  2023-02-28               30       place               6
#
# ...

# %%
list(kaggle_city_raw.columns)
# Out:
# ['period_begin',
#  'period_end',
#  'period_duration',
#  'region_type',
#  'region_type_id',
#  'table_id',
#  'is_seasonally_adjusted',
#  'region',
#  'city',
#  'state',
#  'state_code',
#  'property_type',
#  'property_type_id',
#  'median_sale_price',
#  'median_sale_price_mom',
#  'median_sale_price_yoy',
#  'median_list_price',
#  'median_list_price_mom',
#  'median_list_price_yoy',
#  'median_ppsf',
#  'median_ppsf_mom',
#  'median_ppsf_yoy',
#  'median_list_ppsf',
#  'median_list_ppsf_mom',
#  'median_list_ppsf_yoy',
#  'homes_sold',
#  'homes_sold_mom',
#  'homes_sold_yoy',
#  'pending_sales',
#  'pending_sales_mom',
#  'pending_sales_yoy',
#  'new_listings',
#  'new_listings_mom',
#  'new_listings_yoy',
#  'inventory',
#  'inventory_mom',
#  'inventory_yoy',
#  'months_of_supply',
#  'months_of_supply_mom',
#  'months_of_supply_yoy',
#  'median_dom',
#  'median_dom_mom',
#  'median_dom_yoy',
#  'avg_sale_to_list',
#  'avg_sale_to_list_mom',
#  'avg_sale_to_list_yoy',
# ...

# %%
washington_kaggle = kaggle_city_raw[kaggle_city_raw["state"]=="Washington"]
washington_kaggle
# Out:
#         period_begin  period_end  period_duration region_type  region_type_id  \
# 64        2013-12-01  2013-12-31               30       place               6
# 170       2022-03-01  2022-03-31               30       place               6
# 172       2014-01-01  2014-01-31               30       place               6
# 176       2012-12-01  2012-12-31               30       place               6
# 224       2013-09-01  2013-09-30               30       place               6
# ...              ...         ...              ...         ...             ...
# 5244802   2018-06-01  2018-06-30               30       place               6
# 5244868   2018-06-01  2018-06-30               30       place               6
# 5244877   2018-09-01  2018-09-30               30       place               6
# 5244981   2022-10-01  2022-10-31               30       place               6
# 5245026   2013-06-01  2013-06-30               30       place               6
#
# ...

# %%
washington_kaggle.to_csv("data_sources/Kaggle_Washington.csv", index=False)
